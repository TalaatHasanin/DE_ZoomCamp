# %%
import pandas as pd
from sqlalchemy import create_engine
import os

# %%
pd.__version__
# Out:
# '2.2.0'

# %%
csv_url = 'https://raw.githubusercontent.com/TalaatHasanin/DE_ZoomCamp/main/module1/docker/output.csv'
os.system(f"wget {csv_url} -O test.csv")
test_df = pd.read_csv("test.csv")
test_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 csv_url = 'https://raw.githubusercontent.com/TalaatHasanin/DE_ZoomCamp/main/module1/docker/output.csv'
#       2 os.system(f"wget {csv_url} -O test.csv")
# ----> 3 test_df = pd.read_csv("test.csv")
#       4 test_df
#
# ...

# %%
df = pd.read_csv("yellow_tripdata_2021-01.csv", nrows=100)

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:30:00   2021-01-01 00:36:00                1
# 1          1  2021-01-01 00:51:00   2021-01-01 00:52:00                1
# 2          1  2021-01-01 00:43:00   2021-01-01 01:11:00                1
# 3          1  2021-01-01 00:15:00   2021-01-01 00:31:00                0
# 4          2  2021-01-01 00:31:00   2021-01-01 00:48:00                1
# ..       ...                  ...                   ...              ...
# 95         2  2021-01-01 00:12:00   2021-01-01 00:26:00                1
# 96         2  2021-01-01 00:23:00   2021-01-01 00:35:00                2
# 97         2  2021-01-01 00:46:00   2021-01-01 00:54:00                2
# 98         2  2021-01-01 00:28:00   2021-01-01 00:51:00                1
# 99         2  2021-01-01 00:42:00   2021-01-01 00:54:00                3
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
connection = engine.connect()

# %%
schema = pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine)
print(schema)
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv("yellow_tripdata_2021-01.csv", iterator=True, chunksize=100000)

# %%
df = next(df_iter)
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1        1/1/2021 0:30         1/1/2021 0:36                1
# 1             1        1/1/2021 0:51         1/1/2021 0:52                1
# 2             1        1/1/2021 0:43         1/1/2021 1:11                1
# 3             1        1/1/2021 0:15         1/1/2021 0:31                0
# 4             2        1/1/2021 0:31         1/1/2021 0:48                1
# ...         ...                  ...                   ...              ...
# 99995         1       1/4/2021 14:04        1/4/2021 14:08                3
# 99996         1       1/4/2021 14:18        1/4/2021 14:35                2
# 99997         1       1/4/2021 14:42        1/4/2021 14:59                2
# 99998         2       1/4/2021 14:39        1/4/2021 15:09                2
# 99999         2       1/4/2021 14:49        1/4/2021 14:54                5
#
# ...

# %%
len(df)
# Out:
# 100000

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: total: 3.36 s
# Wall time: 9.22 s
# 1000

# %%
from time import time

# %%
while True:
    df = next(df_iter)
    t_begin = time()
    
    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    
    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
    t_end = time()
    
    print(f'inserted another chunck...., took {t_end - t_begin:.3f}')
# Out:
# inserted another chunck...., took 8.550
# inserted another chunck...., took 9.606
# inserted another chunck...., took 8.736
# inserted another chunck...., took 8.678
# inserted another chunck...., took 8.405
# inserted another chunck...., took 8.231
# inserted another chunck...., took 8.744
# inserted another chunck...., took 8.926
# inserted another chunck...., took 9.919
# inserted another chunck...., took 4.897
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[17], line 2
#       1 while True:
# ----> 2     df = next(df_iter)
#       3     t_begin = time()
#       5     df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#
# File ~\Documents\Github\DE_ZoomCamp\.venv\lib\site-packages\pandas\io\parsers\readers.py:1841, in TextFileReader.__next__(self)
#    1839 def __next__(self) -> DataFrame:
#    1840     try:
# -> 1841         return self.get_chunk()
# ...
